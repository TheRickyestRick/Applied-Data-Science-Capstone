# %% [markdown]
# The objective of this Notebook is to perform the Data Science Capstone Project, week 3 assignment.

# %% [markdown]
# # First Part: Dataframe creation

# %%
import pandas as pd
import numpy as np

# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/dd/ba/a0e6866057fc0bbd17192925c1d63a3b85cf522965de9bc02364d08e5b84/lxml-4.5.0-cp36-cp36m-manylinux1_x86_64.whl (5.8MB)
#      |████████████████████████████████| 5.8MB 4.1MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geocoder
# Out:
# Requirement already satisfied: geocoder in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: click in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (7.1.1)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (2.23.0)
# Requirement already satisfied: ratelim in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (1.14.0)
# Requirement already satisfied: future in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2.9)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ratelim->geocoder) (4.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#first we will read the table from the wikipedia page.

url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

#pd.read_html returns a list (of dataframes). There is only one and it can be accessed as the first element of the list.
df=pd.read_html(url)
df=df[0]
df
# Out:
#     Postal code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178  Mimico NW / The Queensway West / South of Bloo...
# 179                                                NaN
#
# [180 rows x 3 columns]

# %%
# We will now drop the 'not assigned' values

df=df[df.Borough != 'Not assigned']

df.reset_index(drop=True,inplace=True)

df.isna().sum()
# Out:
# Postal code     0
# Borough         0
# Neighborhood    0
# dtype: int64

# %%
# We will now replace the 'NaN' values for neighborhood for their corresponding borough


for i, neighborhood in zip(df.index, df.Neighborhood):
    
    if neighborhood == 'NaN':
        df.replace({df['Neighborhood'][i]: df['Borough'][i]}, inplace=True)

# %%
# We can verify that no NaN remain

print(sum(df['Neighborhood']=='NaN'))
# Out:
# 0

# %%
# We will identify postal codes that share a neighborhood, but will clean later

indices = [index for index, element in enumerate(df['Neighborhood'].duplicated()) if element == True]
indices
df.iloc[indices]
# Out:
#    Postal code     Borough Neighborhood
# 13         M3C  North York    Don Mills
# 46         M3L  North York    Downsview
# 53         M3M  North York    Downsview
# 60         M3N  North York    Downsview
# 72         M2R  North York   Willowdale

# %%
# Lets change the '/' for ',':

for index in range(len(df.Neighborhood)):
    
    df['Neighborhood'][index]=df['Neighborhood'][index].replace('/',',')
    
    
df
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park , Harbourfront
# 3                    Lawrence Manor , Lawrence Heights
# 4         Queen's Park , Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway , Montgomery Road , Old Mill North
# 99                                Church and Wellesley
# 100              Business reply mail Processing CentrE
# 101  Old Mill South , King's Mill Park , Sunnylea ,...
# 102  Mimico NW , The Queensway West , South of Bloo...
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Important remark!: even though there are no different neighborhoods sharing a postal code (as they are already grouped in the wikipedia table), there are neighborhoods with several postal codes. This will be solved later on as we will group them and calculate the mean coordinates at the same time

# %%
#we can see that the number of unique neighborhoods is smaller than the number of postal codes

len(df.Neighborhood.unique())
# Out:
# 98

# %% [markdown]
# # Part two: Coordinate Retrieval

# %% [markdown]
# ## Below code should not be run (as it will time out), geocoder does not seem to be working: plan B just after

# %%
import geocoder # import geocoder

# The code below timed out so I will go with plan B: retrieving coordinates from the url
latitude=[]
longitude=[]
#Create a bigger loop to move through post codes
j=0
for postal_code in df['Postal code']:
# initialize your variable to None
    lat_lng_coords = None
    i=0
# loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
        i=i+1 
        print(i)
        
    latitude.append(lat_lng_coords[0])
    longitude.append(lat_lng_coords[1])
    j=j+1
    print(j)
    
df['Latitude']=latitude
df['Longitude']=longitude
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-4a5427728164> in <module>
#      12 # loop until you get the coordinates
#      13     while(lat_lng_coords is None):
# ---> 14         g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#      15         lat_lng_coords = g.latlng
#      16         i=i+1
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/api.py in google(location, **kwargs)
#     230         > elevation
#     231     """
# --> 232     return get(location, provider='google', **kwargs)
#     233
#     234
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/base.py in __init__(self, location, **kwargs)
#     408
#     409         # query and parse results
# --> 410         self._initialize()
#     411
#     412     def __getitem__(self, key):
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/base.py in _initialize(self)
#     455     def _initialize(self):
#     456         # query URL and get valid JSON (also stored in self.json)
# --> 457         json_response = self._connect()
#     458
#     459         # catch errors
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/base.py in _connect(self)
#     482                 headers=self.headers,
#     483                 timeout=self.timeout,
# --> 484                 proxies=self.proxies
#     485             )
#     486
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/google.py in rate_limited_get(self, *args, **kwargs)
#     267             return self.rate_limited_get_for_work(*args, **kwargs)
#     268         else:
# --> 269             return self.rate_limited_get_for_dev(*args, **kwargs)
#     270
#     271     @ratelim.greedy(2500, 60 * 60 * 24)
#
# <decorator-gen-128> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# ~/conda/envs/python/lib/python3.6/site-packages/ratelim/__init__.py in wrapped_f(self, f, *args, **kwargs)
#      31             time_delta = int(time_delta.total_seconds()) + 1
#      32             if time_delta <= self.__time_interval:
# ---> 33                 time.sleep(self.__time_interval - time_delta + 1)
#      34                 self.__numcalls = 0
#      35                 self.__last_reset = datetime.datetime.now()
#
# KeyboardInterrupt:

# %%
url2='http://cocl.us/Geospatial_data'
df2=pd.read_csv(url2)
df2
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
df['Latitude']=df['Postal code']
df['Longitude']=df['Postal code']
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for j,postal_code in zip(df2.index, df2['Postal Code']):
    for index in df.index:
        if df['Postal code'][index]==postal_code:
            df['Latitude'][index]=df2['Latitude'][j]
            df['Longitude'][index]=df2['Longitude'][j]
            
df
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood Latitude Longitude
# 0                                            Parkwoods  43.7533  -79.3297
# 1                                     Victoria Village  43.7259  -79.3156
# 2                           Regent Park , Harbourfront  43.6543  -79.3606
# 3                    Lawrence Manor , Lawrence Heights  43.7185  -79.4648
# 4         Queen's Park , Ontario Provincial Government  43.6623  -79.3895
# ..                                                 ...      ...       ...
# 98     The Kingsway , Montgomery Road , Old Mill North  43.6537  -79.5069
# 99                                Church and Wellesley  43.6659  -79.3832
# 100              Business reply mail Processing CentrE  43.6627  -79.3216
# 101  Old Mill South , King's Mill Park , Sunnylea ,...  43.6363  -79.4985
# 102  Mimico NW , The Queensway West , South of Bloo...  43.6288   -79.521
#
# [103 rows x 5 columns]

# %% [markdown]
# ### We will now group the postal codes that are shared by multiple neighborhoods and recalculate the coordinates for the neighborhoods as the mean for the different postal codes in them:

# %%
df['Latitude']=df['Latitude'].astype('float')
df['Longitude']=df['Longitude'].astype('float')
df_aux=df.drop(['Postal code','Borough'],axis=1)


df_aux=df_aux.groupby('Neighborhood').mean()
df_aux
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                     Latitude  Longitude
# Neighborhood
# Agincourt                                          43.794200 -79.262029
# Alderwood , Long Branch                            43.602414 -79.543484
# Bathurst Manor , Wilson Heights , Downsview North  43.754328 -79.442259
# Bayview Village                                    43.786947 -79.385975
# Bedford Park , Lawrence Manor East                 43.733283 -79.419750
# ...                                                      ...        ...
# Willowdale , Newtonbrook                           43.789053 -79.408493
# Woburn                                             43.770992 -79.216917
# Woodbine Heights                                   43.695344 -79.318389
# York Mills , Silver Hills                          43.757490 -79.374714
# York Mills West                                    43.752758 -79.400049
#
# [98 rows x 2 columns]

# %%
df_aux['Postal code']='NaN'
df_aux['Borough']='NaN'
df_aux.reset_index()
for postal_code, neighborhood, borough in zip(df['Postal code'], df['Neighborhood'], df['Borough']):
    if df_aux.loc[neighborhood,'Postal code']=='NaN':
        df_aux.loc[neighborhood,'Postal code']=postal_code
        df_aux.loc[neighborhood,'Borough']=borough
    else:
        df_aux.loc[neighborhood,'Postal code']=df_aux.loc[neighborhood,'Postal code']+', ' + postal_code

# %%
df=df_aux

# %%
df.reset_index(inplace=True)

# %% [markdown]
# # Part Three: Clustering and Reporting

# %% [markdown]
# We will now cluster the neighborhoods using K-means using data from the Foursquare API

# %%
CLIENT_ID = '4U0ND42NTP142QAL52MLARWTMECJTHOQIWD5ZQFZKV1BUJCZ' # your Foursquare ID
CLIENT_SECRET = '1RVKEFT5TDWCQG320UAQ45I5BV1YG53HU0DWWM3NFSONKR5H' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
# new dataframe to contain feature informations
df3=df[['Neighborhood']]

df3
# Out:
#                                          Neighborhood
# 0                                           Agincourt
# 1                             Alderwood , Long Branch
# 2   Bathurst Manor , Wilson Heights , Downsview North
# 3                                     Bayview Village
# 4                  Bedford Park , Lawrence Manor East
# ..                                                ...
# 93                           Willowdale , Newtonbrook
# 94                                             Woburn
# 95                                   Woodbine Heights
# 96                          York Mills , Silver Hills
# 97                                    York Mills West
#
# [98 rows x 1 columns]

# %% [markdown]
# ## Let us retrieve the venues for all the neighborhoods:

# %%
import requests

# a loop that runs through the neighborhoods
LIMIT=100
radius=500

# Note: with the objective of clustering the neighborhoods, I will only be looking at the percentage of venues in each category and therefore, I will only retrieve this information)
venues_info=[]

for neighborhood_name, neighborhood_latitude, neighborhood_longitude in zip(df.Neighborhood, df.Latitude, df.Longitude):
    
    #setup the API request URL

    search_query=''
    url= 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, neighborhood_latitude, neighborhood_longitude, VERSION, search_query, radius, LIMIT)

    results = requests.get(url).json()["response"]['venues']
    
    for v in results:
        try:
            venues_info.append([v['categories'][0]['name'], neighborhood_name])
        except:
            pass

# %%
df_venues=pd.DataFrame(venues_info)

# %%
df_venues.rename({0: 'Category', 1:'Neighborhood'}, axis=1, inplace=True)

# %% [markdown]
# ## We 'One-hot code' all categories and retrieve the most common venues per neighborhood (in relative terms, that's why we use means):

# %%
dfx=pd.get_dummies(df_venues['Category'])

# %%
df_features=df_venues.merge(dfx, left_index=True, right_index=True)
df_features.drop('Category',inplace=True, axis=1)

# %%
df_weightedNhoods=df_features.groupby('Neighborhood').mean()

# %%
df_weightedNhoods
# Out:
#                                                    ATM  Accessories Store  \
# Neighborhood
# Agincourt                                          0.0                0.0
# Alderwood , Long Branch                            0.0                0.0
# Bathurst Manor , Wilson Heights , Downsview North  0.0                0.0
# Bayview Village                                    0.0                0.0
# Bedford Park , Lawrence Manor East                 0.0                0.0
# ...                                                ...                ...
# Willowdale , Newtonbrook                           0.0                0.0
# Woburn                                             0.0                0.0
# Woodbine Heights                                   0.0                0.0
# York Mills , Silver Hills                          0.0                0.0
# York Mills West                                    0.0                0.0
#
#                                                    Acupuncturist  \
# Neighborhood
# Agincourt                                               0.000000
# Alderwood , Long Branch                                 0.000000
# Bathurst Manor , Wilson Heights , Downsview North       0.000000
# Bayview Village                                         0.011364
# Bedford Park , Lawrence Manor East                      0.000000
# ...                                                          ...
# Willowdale , Newtonbrook                                0.000000
# Woburn                                                  0.000000
# Woodbine Heights                                        0.000000
# York Mills , Silver Hills                               0.000000
# York Mills West                                         0.000000
#
#                                                    Adult Boutique  \
# Neighborhood
# Agincourt                                                     0.0
# Alderwood , Long Branch                                       0.0
# Bathurst Manor , Wilson Heights , Downsview North             0.0
# Bayview Village                                               0.0
# Bedford Park , Lawrence Manor East                            0.0
# ...                                                           ...
# Willowdale , Newtonbrook                                      0.0
# Woburn                                                        0.0
# Woodbine Heights                                              0.0
# York Mills , Silver Hills                                     0.0
# York Mills West                                               0.0
#
#                                                    Advertising Agency  \
# Neighborhood
# Agincourt                                                         0.0
# Alderwood , Long Branch                                           0.0
# Bathurst Manor , Wilson Heights , Downsview North                 0.0
# Bayview Village                                                   0.0
# Bedford Park , Lawrence Manor East                                0.0
# ...                                                               ...
# Willowdale , Newtonbrook                                          0.0
# Woburn                                                            0.0
# Woodbine Heights                                                  0.0
# York Mills , Silver Hills                                         0.0
# York Mills West                                                   0.0
#
#                                                    Afghan Restaurant  \
# Neighborhood
# Agincourt                                                        0.0
# Alderwood , Long Branch                                          0.0
# Bathurst Manor , Wilson Heights , Downsview North                0.0
# Bayview Village                                                  0.0
# Bedford Park , Lawrence Manor East                               0.0
# ...                                                              ...
# Willowdale , Newtonbrook                                         0.0
# Woburn                                                           0.0
# Woodbine Heights                                                 0.0
# York Mills , Silver Hills                                        0.0
# York Mills West                                                  0.0
#
#                                                    African Restaurant  \
# Neighborhood
# Agincourt                                                         0.0
# Alderwood , Long Branch                                           0.0
# Bathurst Manor , Wilson Heights , Downsview North                 0.0
# Bayview Village                                                   0.0
# Bedford Park , Lawrence Manor East                                0.0
# ...                                                               ...
# Willowdale , Newtonbrook                                          0.0
# Woburn                                                            0.0
# Woodbine Heights                                                  0.0
# York Mills , Silver Hills                                         0.0
# York Mills West                                                   0.0
#
#                                                    Airport  \
# Neighborhood
# Agincourt                                              0.0
# Alderwood , Long Branch                                0.0
# Bathurst Manor , Wilson Heights , Downsview North      0.0
# Bayview Village                                        0.0
# Bedford Park , Lawrence Manor East                     0.0
# ...                                                    ...
# Willowdale , Newtonbrook                               0.0
# Woburn                                                 0.0
# Woodbine Heights                                       0.0
# York Mills , Silver Hills                              0.0
# York Mills West                                        0.0
#
#                                                    Airport Food Court  \
# Neighborhood
# Agincourt                                                         0.0
# Alderwood , Long Branch                                           0.0
# Bathurst Manor , Wilson Heights , Downsview North                 0.0
# Bayview Village                                                   0.0
# Bedford Park , Lawrence Manor East                                0.0
# ...                                                               ...
# Willowdale , Newtonbrook                                          0.0
# Woburn                                                            0.0
# Woodbine Heights                                                  0.0
# York Mills , Silver Hills                                         0.0
# York Mills West                                                   0.0
#
#                                                    Airport Gate  ...  \
# Neighborhood                                                     ...
# Agincourt                                                   0.0  ...
# Alderwood , Long Branch                                     0.0  ...
# Bathurst Manor , Wilson Heights , Downsview North           0.0  ...
# Bayview Village                                             0.0  ...
# Bedford Park , Lawrence Manor East                          0.0  ...
# ...                                                         ...  ...
# Willowdale , Newtonbrook                                    0.0  ...
# Woburn                                                      0.0  ...
# Woodbine Heights                                            0.0  ...
# York Mills , Silver Hills                                   0.0  ...
# York Mills West                                             0.0  ...
#
#                                                    Waste Facility  Water Park  \
# Neighborhood
# Agincourt                                                     0.0         0.0
# Alderwood , Long Branch                                       0.0         0.0
# Bathurst Manor , Wilson Heights , Downsview North             0.0         0.0
# Bayview Village                                               0.0         0.0
# Bedford Park , Lawrence Manor East                            0.0         0.0
# ...                                                           ...         ...
# Willowdale , Newtonbrook                                      0.0         0.0
# Woburn                                                        0.0         0.0
# Woodbine Heights                                              0.0         0.0
# York Mills , Silver Hills                                     0.0         0.0
# York Mills West                                               0.0         0.0
#
#                                                    Wine Bar  Wine Shop  \
# Neighborhood
# Agincourt                                               0.0   0.000000
# Alderwood , Long Branch                                 0.0   0.000000
# Bathurst Manor , Wilson Heights , Downsview North       0.0   0.000000
# Bayview Village                                         0.0   0.000000
# Bedford Park , Lawrence Manor East                      0.0   0.000000
# ...                                                     ...        ...
# Willowdale , Newtonbrook                                0.0   0.011111
# Woburn                                                  0.0   0.000000
# Woodbine Heights                                        0.0   0.000000
# York Mills , Silver Hills                               0.0   0.000000
# York Mills West                                         0.0   0.000000
#
#                                                      Winery  Wings Joint  \
# Neighborhood
# Agincourt                                          0.000000     0.000000
# Alderwood , Long Branch                            0.000000     0.000000
# Bathurst Manor , Wilson Heights , Downsview North  0.000000     0.000000
# Bayview Village                                    0.000000     0.000000
# Bedford Park , Lawrence Manor East                 0.000000     0.011494
# ...                                                     ...          ...
# Willowdale , Newtonbrook                           0.011111     0.000000
# Woburn                                             0.000000     0.000000
# Woodbine Heights                                   0.000000     0.000000
# York Mills , Silver Hills                          0.000000     0.000000
# York Mills West                                    0.011364     0.000000
#
#                                                    Women's Store  Yoga Studio  \
# Neighborhood
# Agincourt                                                    0.0     0.000000
# Alderwood , Long Branch                                      0.0     0.000000
# Bathurst Manor , Wilson Heights , Downsview North            0.0     0.011236
# Bayview Village                                              0.0     0.000000
# Bedford Park , Lawrence Manor East                           0.0     0.011494
# ...                                                          ...          ...
# Willowdale , Newtonbrook                                     0.0     0.000000
# Woburn                                                       0.0     0.000000
# Woodbine Heights                                             0.0     0.000000
# York Mills , Silver Hills                                    0.0     0.000000
# York Mills West                                              0.0     0.011364
#
#                                                    Zoo  Zoo Exhibit
# Neighborhood
# Agincourt                                          0.0          0.0
# Alderwood , Long Branch                            0.0          0.0
# Bathurst Manor , Wilson Heights , Downsview North  0.0          0.0
# Bayview Village                                    0.0          0.0
# Bedford Park , Lawrence Manor East                 0.0          0.0
# ...                                                ...          ...
# Willowdale , Newtonbrook                           0.0          0.0
# Woburn                                             0.0          0.0
# Woodbine Heights                                   0.0          0.0
# York Mills , Silver Hills                          0.0          0.0
# York Mills West                                    0.0          0.0
#
# [98 rows x 493 columns]

# %% [markdown]
# ## Now we will use the K-Means method to cluster the neighborhoods

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# We will cluster the neighborhoods using K-means

# %%
# set number of clusters
kclusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_weightedNhoods)
len(kmeans.labels_)
# Out:
# 98

# %%
df.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
df
# Out:
#     Cluster Labels                                       Neighborhood  \
# 0                4                                          Agincourt
# 1                4                            Alderwood , Long Branch
# 2                3  Bathurst Manor , Wilson Heights , Downsview North
# 3                3                                    Bayview Village
# 4                0                 Bedford Park , Lawrence Manor East
# ..             ...                                                ...
# 93               0                           Willowdale , Newtonbrook
# 94               0                                             Woburn
# 95               0                                   Woodbine Heights
# 96               0                          York Mills , Silver Hills
# 97               3                                    York Mills West
#
#      Latitude  Longitude Postal code      Borough
# 0   43.794200 -79.262029         M1S  Scarborough
# 1   43.602414 -79.543484         M8W    Etobicoke
# 2   43.754328 -79.442259         M3H   North York
# 3   43.786947 -79.385975         M2K   North York
# 4   43.733283 -79.419750         M5M   North York
# ..        ...        ...         ...          ...
# 93  43.789053 -79.408493         M2M   North York
# 94  43.770992 -79.216917         M1G  Scarborough
# 95  43.695344 -79.318389         M4C    East York
# 96  43.757490 -79.374714         M2L   North York
# 97  43.752758 -79.400049         M2P   North York
#
# [98 rows x 6 columns]

# %% [markdown]
# ## We will now create a map

# %%
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
latitude=df['Latitude'].mean()
longitude=df['Longitude'].mean()
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df['Latitude'], df['Longitude'], df['Neighborhood'],df['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Interpreting the clusters

# %%
# We will create a dataframe to group the neighborhoods according to their cluster label. Then we will find which types of features are more characteristic for each cluster:

df_clusters=df_weightedNhoods.reset_index()

# %%
#df_clusters.drop('Neighborhood', axis=1, inplace=True)
df_clusters=df_clusters.groupby('Cluster Labels').mean()
df_clusters
# Out:
#                      ATM  Accessories Store  Acupuncturist  Adult Boutique  \
# Cluster Labels
# 0               0.000358           0.002035       0.000000        0.000000
# 1               0.000000           0.005376       0.000000        0.000000
# 2               0.000000           0.000000       0.000000        0.000000
# 3               0.000745           0.000000       0.001719        0.000654
# 4               0.001266           0.002530       0.000000        0.000000
#
#                 Advertising Agency  Afghan Restaurant  African Restaurant  \
# Cluster Labels
# 0                         0.000359           0.000184            0.001160
# 1                         0.000000           0.000000            0.000000
# 2                         0.000000           0.000000            0.000000
# 3                         0.000774           0.001176            0.000000
# 4                         0.003198           0.000619            0.001892
#
#                  Airport  Airport Food Court  Airport Gate  ...  \
# Cluster Labels                                              ...
# 0               0.000000            0.000000      0.000000  ...
# 1               0.000000            0.000000      0.000000  ...
# 2               0.037037            0.018519      0.222222  ...
# 3               0.000000            0.000000      0.000000  ...
# 4               0.000619            0.000000      0.000000  ...
#
#                 Waste Facility  Water Park  Wine Bar  Wine Shop    Winery  \
# Cluster Labels
# 0                     0.000193    0.000216  0.001118   0.000997  0.001532
# 1                     0.000000    0.000000  0.000000   0.000000  0.005376
# 2                     0.000000    0.000000  0.000000   0.000000  0.000000
# 3                     0.000000    0.001225  0.000000   0.000692  0.000668
# 4                     0.000000    0.000633  0.000000   0.000654  0.000000
#
#                 Wings Joint  Women's Store  Yoga Studio       Zoo  Zoo Exhibit
# Cluster Labels
# 0                  0.001158       0.003912     0.002510  0.000182     0.003021
# 1                  0.000000       0.000000     0.000000  0.000000     0.000000
# 2                  0.000000       0.000000     0.000000  0.000000     0.000000
# 3                  0.001176       0.000692     0.001329  0.000000     0.000000
# 4                  0.000000       0.003184     0.002129  0.000000     0.000654
#
# [5 rows x 493 columns]

# %%
# Lets find the main types of venue for each cluster

# Let's create a dataframe to store the results


clusters_main_features=[]
for i in df_clusters.index:

    cluster_sorted=df_clusters.iloc[i].sort_values(ascending=False)
    clusters_main_features.append(cluster_sorted.index[0:5])
    
clusters_main_features=pd.DataFrame(clusters_main_features)
clusters_main_features.rename(columns={0:'First most common venue', 1:'Second most common venue', 2:'Third most common venue', 3:'Fourth most common venue', 4:'Fifht most common venue'},inplace=True)

# %% [markdown]
# Based on the most common venues for each cluster, we can easily find names for them

# %%
# In my particular case (if we rerun the kernel it might not hold), this is a proposed classification for the clusters:

clusters_main_features.rename(index={0:'Office district', 1:'Commercial area', 2:'Airport area', 3:'Residential area', 4:'Mixed office and residential area'},inplace=True)
clusters_main_features.reset_index(inplace=True)

# %%
clusters_main_features.rename(columns={'index':'Area Type'}, inplace=True)
clusters_main_features
# Out:
#                            Area Type  \
# 0                    Office district
# 1                    Commercial area
# 2                       Airport area
# 3                   Residential area
# 4  Mixed office and residential area
#
#                     First most common venue Second most common venue  \
# 0                                    Office       Salon / Barbershop
# 1                           Automotive Shop                 Building
# 2                              Airport Gate          Airport Service
# 3  Residential Building (Apartment / Condo)                   Office
# 4                                    Office                 Building
#
#   Third most common venue                  Fourth most common venue  \
# 0                    Park                                    Church
# 1  Furniture / Home Store                               Gas Station
# 2           Moving Target                          Airport Terminal
# 3                Building                                      Park
# 4         Automotive Shop  Residential Building (Apartment / Condo)
#
#   Fifht most common venue
# 0                Building
# 1                  Office
# 2           Boat or Ferry
# 3         Doctor's Office
# 4             Coffee Shop

# %%
df['Area Type']=''
for i in df.index:
   
    df['Area Type'][i]=clusters_main_features.loc[df['Cluster Labels'][i],'Area Type']

df
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#     Cluster Labels                                       Neighborhood  \
# 0                4                                          Agincourt
# 1                4                            Alderwood , Long Branch
# 2                3  Bathurst Manor , Wilson Heights , Downsview North
# 3                3                                    Bayview Village
# 4                0                 Bedford Park , Lawrence Manor East
# ..             ...                                                ...
# 93               0                           Willowdale , Newtonbrook
# 94               0                                             Woburn
# 95               0                                   Woodbine Heights
# 96               0                          York Mills , Silver Hills
# 97               3                                    York Mills West
#
#      Latitude  Longitude Postal code      Borough  \
# 0   43.794200 -79.262029         M1S  Scarborough
# 1   43.602414 -79.543484         M8W    Etobicoke
# 2   43.754328 -79.442259         M3H   North York
# 3   43.786947 -79.385975         M2K   North York
# 4   43.733283 -79.419750         M5M   North York
# ..        ...        ...         ...          ...
# 93  43.789053 -79.408493         M2M   North York
# 94  43.770992 -79.216917         M1G  Scarborough
# 95  43.695344 -79.318389         M4C    East York
# 96  43.757490 -79.374714         M2L   North York
# 97  43.752758 -79.400049         M2P   North York
#
#                             Area Type
# 0   Mixed office and residential area
# 1   Mixed office and residential area
# 2                    Residential area
# 3                    Residential area
# 4                     Office district
# ..                                ...
# 93                    Office district
# 94                    Office district
# 95                    Office district
# 96                    Office district
# 97                   Residential area
#
# [98 rows x 7 columns]

# %% [markdown]
# ### Final map with legend

# %%
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
latitude=df['Latitude'].mean()
longitude=df['Longitude'].mean()
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
feature_group=[]
for i in range(kclusters):
    feature_group.append( folium.FeatureGroup(name=clusters_main_features.loc[i,'Area Type']))

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster, cluster_name in zip(df['Latitude'], df['Longitude'], df['Neighborhood'],df['Cluster Labels'], df['Area Type']):
    label = folium.Popup(str(cluster_name) + ': ' + str(poi), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(feature_group[cluster]),

for i in range(kclusters):
    map_clusters.add_child(feature_group[i])
    
map_clusters.add_child(folium.map.LayerControl())
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Please note on the map above the layer control, which allows to select and de-select certain clusters
